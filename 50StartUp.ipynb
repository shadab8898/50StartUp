# %% [markdown]
# # Profit Prediction (50 Startup)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\BORN 2 CODE\Downloads\50_Startups.csv")

# %%
df.head(5)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %% [markdown]
# # Visualisation

# %%
plt.figure(figsize=(12,6))
sns.distplot(df['R&D Spend'])
plt.show()
# Out:
# C:\Users\BORN 2 CODE\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,6))
sns.distplot(df['Administration'])
plt.show()
# Out:
# C:\Users\BORN 2 CODE\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,6))
sns.distplot(df['Marketing Spend'])
plt.show()
# Out:
# C:\Users\BORN 2 CODE\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['State'])
plt.show()
# Out:
# C:\Users\BORN 2 CODE\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,6))
sns.histplot(df['Profit'])
plt.show()

# %%
plt.boxplot(df['Profit'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x267bc712640>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x267bbde7820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x267bc7b0d60>],
#  'medians': [<matplotlib.lines.Line2D at 0x267bc7a66d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x267bc7b88e0>],
#  'means': []}

# %%
plt.boxplot(df['R&D Spend'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x267bb80d5b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x267bb7bce50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x267bb80d2b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x267bbe45e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x267bbe452b0>],
#  'means': []}

# %%
plt.boxplot(df['Administration'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x267bb153040>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x267bb7faa30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x267bb153370>],
#  'medians': [<matplotlib.lines.Line2D at 0x267bbcbbaf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x267bbcbbf10>],
#  'means': []}

# %%
plt.boxplot(df['Marketing Spend'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x267bb5fd4f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x267bb4819d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x267bbcd1970>],
#  'medians': [<matplotlib.lines.Line2D at 0x267bbd48e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x267bbd480a0>],
#  'means': []}

# %%
plt.figure(figsize=(12,6))
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Correlation

# %%
correlation = df.corr()

# %%
#construct the heatmap to understand the correlation between the columns
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f',annot=True,annot_kws={'size':8},cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
print(df.corr()['Profit'].abs().sort_values(ascending=False))
# Out:
# Profit             1.000000
# R&D Spend          0.972900
# Marketing Spend    0.747766
# Administration     0.200717
# Name: Profit, dtype: float64

# %%
X = df[['R&D Spend','Marketing Spend','Administration']]
Y = df['Profit']

# %%
print(X)
# Out:
#     R&D Spend  Marketing Spend  Administration
# 0   165349.20        471784.10       136897.80
# 1   162597.70        443898.53       151377.59
# 2   153441.51        407934.54       101145.55
# 3   144372.41        383199.62       118671.85
# 4   142107.34        366168.42        91391.77
# 5   131876.90        362861.36        99814.71
# 6   134615.46        127716.82       147198.87
# 7   130298.13        323876.68       145530.06
# 8   120542.52        311613.29       148718.95
# 9   123334.88        304981.62       108679.17
# 10  101913.08        229160.95       110594.11
# 11  100671.96        249744.55        91790.61
# 12   93863.75        249839.44       127320.38
# 13   91992.39        252664.93       135495.07
# 14  119943.24        256512.92       156547.42
# 15  114523.61        261776.23       122616.84
# 16   78013.11        264346.06       121597.55
# 17   94657.16        282574.31       145077.58
# 18   91749.16        294919.57       114175.79
# ...

# %%
print(Y)
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2, random_state=42)

# %% [markdown]
# # Model

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()
model1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model1.predict(X_test)
Y_pred
# Out:
# array([126703.02716461,  84894.75081556,  98893.41815974,  46501.70815036,
#        129128.39734381,  50992.69486261, 109016.5536578 , 100878.4641454 ,
#         97700.59638629, 113106.15292226])

# %%
Y_test
# Out:
# 13    134307.35
# 39     81005.76
# 30     99937.59
# 45     64926.08
# 17    125370.37
# 48     35673.41
# 26    105733.54
# 25    107404.34
# 32     97427.84
# 19    122776.86
# Name: Profit, dtype: float64

# %%
model1.score(X,Y)
# Out:
# 0.9496916573955003
